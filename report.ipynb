# %%
import pandas as pd
from tabulate import tabulate

# %%
# Select a Dataset
df = pd.read_csv('archive/country_wise_latest.csv')

# %%
#Cleans rows with missing value
# df = df.dropna()
# removed NaN/inf values
df = df.replace([float('inf'), float('-inf')], pd.NA).dropna()

# %%
#Check data type and structures
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          182 non-null    object
#  1   Confirmed               182 non-null    int64
#  2   Deaths                  182 non-null    int64
#  3   Recovered               182 non-null    int64
#  4   Active                  182 non-null    int64
#  5   New cases               182 non-null    int64
#  6   New deaths              182 non-null    int64
#  7   New recovered           182 non-null    int64
#  8   Deaths / 100 Cases      182 non-null    float64
#  9   Recovered / 100 Cases   182 non-null    float64
#  10  Deaths / 100 Recovered  182 non-null    object
#  11  Confirmed last week     182 non-null    int64
#  12  1 week change           182 non-null    int64
#  13  1 week % increase       182 non-null    float64
#  14  WHO Region              182 non-null    object
# dtypes: float64(3), int64(9), object(3)
# memory usage: 22.8+ KB
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.820000e+02     182.000000  1.820000e+02  1.820000e+02    182.000000
# mean   8.933031e+04    3509.879121  5.202246e+04  3.379797e+04   1248.054945
# std    3.884323e+05   14280.398555  1.926084e+05  2.161344e+05   5786.513060
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.107000e+03      18.250000  7.190000e+02  1.317500e+02      4.000000
# 50%    4.970000e+03     103.500000  3.220000e+03  1.599000e+03     49.000000
# 75%    3.967625e+04     718.250000  2.333350e+04  8.696000e+03    419.750000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   182.000000     182.000000          182.000000             182.000000
# mean     29.615385     959.467033            2.972308              66.601319
# std     121.614850    4252.395043            3.458736              24.307913
# min       0.000000       0.000000            0.000000               0.000000
# 25%       0.000000       0.000000            0.942500              51.770000
# 50%       1.000000      24.000000            2.130000              72.270000
# 75%       5.750000     228.250000            3.715000              87.282500
# max    1076.000000   33728.000000           28.560000             100.000000
#
#        Confirmed last week  1 week change  1 week % increase
# count         1.820000e+02     182.000000         182.000000
# mean          7.966686e+04    9663.450549          13.647912
# std           3.427795e+05   48124.010700          24.791266
# min           1.000000e+01     -47.000000          -3.840000
# 25%           1.045250e+03      47.000000           2.762500
# 50%           4.784000e+03     418.000000           6.890000
# 75%           3.658350e+04    3248.500000          16.927500
# max           3.834677e+06  455582.000000         226.320000

# %%
# List of numerical columns to analyze
numerical_columns = [
    'Confirmed',
    'Deaths',
    'Recovered',
    'Active',
    'New cases',
    'New deaths',
    'New recovered',
    'Deaths / 100 Cases',
    'Recovered / 100 Cases',
    'Deaths / 100 Recovered',
    'Confirmed last week',
    '1 week change',
    '1 week % increase'
]

# Function to calculate and print descriptive statistics for a given column
def print_statistics(column):
    mean_value = df[column].mean()
    median_value = df[column].median()
    mode_value = df[column].mode()[0]
    std_value = df[column].std()
    variance_value = df[column].var()
    min_value = df[column].min()
    max_value = df[column].max()
    range_value = max_value - min_value
    percentile_25 = df[column].quantile(0.25)
    percentile_50 = df[column].quantile(0.50)
    percentile_75 = df[column].quantile(0.75)

    data = [
        ["Mean", f"{mean_value:.0f}"],
        ["Median", f"{median_value:.0f}"],
        ["Mode", f"{mode_value:.0f}"],
        ["Standard Deviation", f"{std_value:.0f}"],
        ["Variance", f"{variance_value:.0f}"],
        ["Min", f"{min_value:.0f}"],
        ["Max", f"{max_value:.0f}"],
        ["Range", f"{range_value:.0f}"],
        ["25th Percentile", f"{percentile_25:.0f}"],
        ["50th Percentile (Median)", f"{percentile_50:.0f}"],
        ["75th Percentile", f"{percentile_75:.0f}"]
    ]

    print(f"\nDescriptive Statistics for {column}")
    print(tabulate(data, headers=["Statistic", "Value"], tablefmt="pretty", floatfmt=".2f"))

for column in numerical_columns:
    print_statistics(column)

# For 'WHO Region'
most_frequent_region = df['WHO Region'].mode()[0]
print("\nMost Frequent WHO Region:", most_frequent_region)
# Out:
# Descriptive Statistics for Confirmed
# +--------------------------+--------------+
# |        Statistic         |    Value     |
# +--------------------------+--------------+
# |           Mean           |    89330     |
# |          Median          |     4970     |
# |           Mode           |      24      |
# |    Standard Deviation    |    388432    |
# |         Variance         | 150879672538 |
# |           Min            |      10      |
# |           Max            |   4290259    |
# |          Range           |   4290249    |
# |     25th Percentile      |     1107     |
# | 50th Percentile (Median) |     4970     |
# |     75th Percentile      |    39676     |
# +--------------------------+--------------+
#
# Descriptive Statistics for Deaths
# +--------------------------+-----------+
# |        Statistic         |   Value   |
# +--------------------------+-----------+
# |           Mean           |   3510    |
# |          Median          |    104    |
# |           Mode           |     0     |
# |    Standard Deviation    |   14280   |
# |         Variance         | 203929783 |
# |           Min            |     0     |
# |           Max            |  148011   |
# |          Range           |  148011   |
# |     25th Percentile      |    18     |
# | 50th Percentile (Median) |    104    |
# |     75th Percentile      |    718    |
# +--------------------------+-----------+
#
# Descriptive Statistics for Recovered
# +--------------------------+-------------+
# |        Statistic         |    Value    |
# +--------------------------+-------------+
# |           Mean           |    52022    |
# |          Median          |    3220     |
# |           Mode           |     18      |
# |    Standard Deviation    |   192608    |
# |         Variance         | 37097999786 |
# |           Min            |      0      |
# |           Max            |   1846641   |
# |          Range           |   1846641   |
# |     25th Percentile      |     719     |
# | 50th Percentile (Median) |    3220     |
# |     75th Percentile      |    23334    |
# +--------------------------+-------------+
#
# Descriptive Statistics for Active
# +--------------------------+-------------+
# |        Statistic         |    Value    |
# +--------------------------+-------------+
# |           Mean           |    33798    |
# |          Median          |    1599     |
# |           Mode           |      0      |
# |    Standard Deviation    |   216134    |
# |         Variance         | 46714064117 |
# |           Min            |      0      |
# |           Max            |   2816444   |
# |          Range           |   2816444   |
# |     25th Percentile      |     132     |
# | 50th Percentile (Median) |    1599     |
# |     75th Percentile      |    8696     |
# +--------------------------+-------------+
#
# Descriptive Statistics for New cases
# +--------------------------+----------+
# |        Statistic         |  Value   |
# +--------------------------+----------+
# |           Mean           |   1248   |
# |          Median          |    49    |
# |           Mode           |    0     |
# |    Standard Deviation    |   5787   |
# |         Variance         | 33483733 |
# |           Min            |    0     |
# |           Max            |  56336   |
# |          Range           |  56336   |
# |     25th Percentile      |    4     |
# | 50th Percentile (Median) |    49    |
# |     75th Percentile      |   420    |
# +--------------------------+----------+
#
# Descriptive Statistics for New deaths
# +--------------------------+-------+
# |        Statistic         | Value |
# +--------------------------+-------+
# |           Mean           |  30   |
# |          Median          |   1   |
# |           Mode           |   0   |
# |    Standard Deviation    |  122  |
# |         Variance         | 14790 |
# |           Min            |   0   |
# |           Max            | 1076  |
# |          Range           | 1076  |
# |     25th Percentile      |   0   |
# | 50th Percentile (Median) |   1   |
# |     75th Percentile      |   6   |
# +--------------------------+-------+
#
# Descriptive Statistics for New recovered
# +--------------------------+----------+
# |        Statistic         |  Value   |
# +--------------------------+----------+
# |           Mean           |   959    |
# |          Median          |    24    |
# |           Mode           |    0     |
# |    Standard Deviation    |   4252   |
# |         Variance         | 18082864 |
# |           Min            |    0     |
# |           Max            |  33728   |
# |          Range           |  33728   |
# |     25th Percentile      |    0     |
# | 50th Percentile (Median) |    24    |
# |     75th Percentile      |   228    |
# +--------------------------+----------+
#
# Descriptive Statistics for Deaths / 100 Cases
# +--------------------------+-------+
# |        Statistic         | Value |
# +--------------------------+-------+
# |           Mean           |   3   |
# |          Median          |   2   |
# |           Mode           |   0   |
# |    Standard Deviation    |   3   |
# |         Variance         |  12   |
# |           Min            |   0   |
# |           Max            |  29   |
# |          Range           |  29   |
# |     25th Percentile      |   1   |
# | 50th Percentile (Median) |   2   |
# |     75th Percentile      |   4   |
# +--------------------------+-------+
#
# Descriptive Statistics for Recovered / 100 Cases
# +--------------------------+-------+
# |        Statistic         | Value |
# +--------------------------+-------+
# |           Mean           |  67   |
# |          Median          |  72   |
# |           Mode           |  100  |
# |    Standard Deviation    |  24   |
# |         Variance         |  591  |
# |           Min            |   0   |
# |           Max            |  100  |
# |          Range           |  100  |
# |     25th Percentile      |  52   |
# | 50th Percentile (Median) |  72   |
# |     75th Percentile      |  87   |
# +--------------------------+-------+
#
# Descriptive Statistics for Deaths / 100 Recovered
# +--------------------------+--------+
# |        Statistic         | Value  |
# +--------------------------+--------+
# |           Mean           |   41   |
# |          Median          |   4    |
# |           Mode           |   0    |
# |    Standard Deviation    |  337   |
# |         Variance         | 113346 |
# |           Min            |   0    |
# |           Max            |  3259  |
# |          Range           |  3259  |
# |     25th Percentile      |   1    |
# | 50th Percentile (Median) |   4    |
# |     75th Percentile      |   6    |
# +--------------------------+--------+
#
# Descriptive Statistics for Confirmed last week
# +--------------------------+--------------+
# |        Statistic         |    Value     |
# +--------------------------+--------------+
# |           Mean           |    79667     |
# |          Median          |     4784     |
# |           Mode           |      19      |
# |    Standard Deviation    |    342779    |
# |         Variance         | 117497769928 |
# |           Min            |      10      |
# |           Max            |   3834677    |
# |          Range           |   3834667    |
# |     25th Percentile      |     1045     |
# | 50th Percentile (Median) |     4784     |
# |     75th Percentile      |    36584     |
# +--------------------------+--------------+
#
# Descriptive Statistics for 1 week change
# +--------------------------+------------+
# |        Statistic         |   Value    |
# +--------------------------+------------+
# |           Mean           |    9663    |
# |          Median          |    418     |
# |           Mode           |     0      |
# |    Standard Deviation    |   48124    |
# |         Variance         | 2315920406 |
# |           Min            |    -47     |
# |           Max            |   455582   |
# |          Range           |   455629   |
# |     25th Percentile      |     47     |
# | 50th Percentile (Median) |    418     |
# |     75th Percentile      |    3248    |
# +--------------------------+------------+
#
# Descriptive Statistics for 1 week % increase
# +--------------------------+-------+
# |        Statistic         | Value |
# +--------------------------+-------+
# |           Mean           |  14   |
# |          Median          |   7   |
# |           Mode           |   0   |
# |    Standard Deviation    |  25   |
# |         Variance         |  615  |
# |           Min            |  -4   |
# |           Max            |  226  |
# |          Range           |  230  |
# |     25th Percentile      |   3   |
# | 50th Percentile (Median) |   7   |
# |     75th Percentile      |  17   |
# +--------------------------+-------+
#
# Most Frequent WHO Region: Europe
