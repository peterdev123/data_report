# %%
import pandas as pd
import tabulate as tabulate

# %%
#Loads the data
df = pd.read_csv('archive/country_wise_latest.csv')

# %%
#Cleans rows with missing value
df = df.dropna()

# %%
#Check data type and structures
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
#  14  WHO Region              187 non-null    object
# dtypes: float64(4), int64(9), object(2)
# memory usage: 22.0+ KB
# c:\Users\petronilo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# std     120.037173    4197.719635            3.454302              26.287694
# min       0.000000       0.000000            0.000000               0.000000
# 25%       0.000000       0.000000            0.945000              48.770000
# 50%       1.000000      22.000000            2.150000              71.320000
# 75%       6.000000     221.000000            3.875000              86.885000
# max    1076.000000   33728.000000           28.560000             100.000000
#
#        Deaths / 100 Recovered  Confirmed last week  1 week change  \
# count                  187.00         1.870000e+02     187.000000
# mean                      inf         7.868248e+04    9448.459893
# std                       NaN         3.382737e+05   47491.127684
# min                      0.00         1.000000e+01     -47.000000
# 25%                      1.45         1.051500e+03      49.000000
# 50%                      3.62         5.020000e+03     432.000000
# 75%                      6.44         3.708050e+04    3172.000000
# max                       inf         3.834677e+06  455582.000000
#
#        1 week % increase
# count         187.000000
# mean           13.606203
# std            24.509838
# min            -3.840000
# 25%             2.775000
# 50%             6.890000
# 75%            16.855000
# max           226.320000

# %%
# List of numerical columns to analyze
numerical_columns = [
    'Confirmed',
    'Deaths',
    'Recovered',
    'Active',
    'New cases',
    'New deaths',
    'New recovered',
    'Deaths / 100 Cases',
    'Recovered / 100 Cases',
    'Deaths / 100 Recovered',
    'Confirmed last week',
    '1 week change',
    '1 week % increase'
]

# Function to calculate and print descriptive statistics for a given column
def print_statistics(column):
    mean_value = df[column].mean()
    median_value = df[column].median()
    mode_value = df[column].mode()[0]
    std_value = df[column].std()
    variance_value = df[column].var()
    min_value = df[column].min()
    max_value = df[column].max()
    range_value = max_value - min_value
    percentile_25 = df[column].quantile(0.25)
    percentile_50 = df[column].quantile(0.50)
    percentile_75 = df[column].quantile(0.75)

    data = [
        ["Mean", f"{mean_value:.0f}"],
        ["Median", f"{median_value:.0f}"],
        ["Mode", f"{mode_value:.0f}"],
        ["Standard Deviation", f"{std_value:.0f}"],
        ["Variance", f"{variance_value:.0f}"],
        ["Min", f"{min_value:.0f}"],
        ["Max", f"{max_value:.0f}"],
        ["Range", f"{range_value:.0f}"],
        ["25th Percentile", f"{percentile_25:.0f}"],
        ["50th Percentile (Median)", f"{percentile_50:.0f}"],
        ["75th Percentile", f"{percentile_75:.0f}"]
    ]

    print(f"\nDescriptive Statistics for {column}")
    print(tabulate(data, headers=["Statistic", "Value"], tablefmt="pretty", floatfmt=".2f"))

for column in numerical_columns:
    print_statistics(column)

# For 'WHO Region'
most_frequent_region = df['WHO Region'].mode()[0]
print("\nMost Frequent WHO Region:", most_frequent_region)
# Out:
# Descriptive Statistics for Confirmed
# +--------------------------+--------------+
# |        Statistic         |    Value     |
# +--------------------------+--------------+
# |           Mean           |    88131     |
# |          Median          |     5059     |
# |           Mode           |      24      |
# |    Standard Deviation    |    383319    |
# |         Variance         | 146933198041 |
# |           Min            |      10      |
# |           Max            |   4290259    |
# |          Range           |   4290249    |
# |     25th Percentile      |     1114     |
# | 50th Percentile (Median) |     5059     |
# |     75th Percentile      |    40460     |
# +--------------------------+--------------+
#
# Descriptive Statistics for Deaths
# +--------------------------+-----------+
# |        Statistic         |   Value   |
# +--------------------------+-----------+
# |           Mean           |   3498    |
# |          Median          |    108    |
# |           Mode           |     0     |
# |    Standard Deviation    |   14100   |
# |         Variance         | 198810070 |
# |           Min            |     0     |
# |           Max            |  148011   |
# |          Range           |  148011   |
# |     25th Percentile      |    18     |
# | 50th Percentile (Median) |    108    |
# |     75th Percentile      |    734    |
# +--------------------------+-----------+
#
# Descriptive Statistics for Recovered
# +--------------------------+-------------+
# |        Statistic         |    Value    |
# +--------------------------+-------------+
# |           Mean           |    50631    |
# |          Median          |    2815     |
# |           Mode           |      0      |
# |    Standard Deviation    |   190188    |
# |         Variance         | 36171547480 |
# |           Min            |      0      |
# |           Max            |   1846641   |
# |          Range           |   1846641   |
# |     25th Percentile      |     626     |
# | 50th Percentile (Median) |    2815     |
# |     75th Percentile      |    22606    |
# +--------------------------+-------------+
#
# Descriptive Statistics for Active
# +--------------------------+-------------+
# |        Statistic         |    Value    |
# +--------------------------+-------------+
# |           Mean           |    34002    |
# |          Median          |    1600     |
# |           Mode           |      0      |
# |    Standard Deviation    |   213326    |
# |         Variance         | 45508056245 |
# |           Min            |      0      |
# |           Max            |   2816444   |
# |          Range           |   2816444   |
# |     25th Percentile      |     142     |
# | 50th Percentile (Median) |    1600     |
# |     75th Percentile      |    9149     |
# +--------------------------+-------------+
#
# Descriptive Statistics for New cases
# +--------------------------+----------+
# |        Statistic         |  Value   |
# +--------------------------+----------+
# |           Mean           |   1223   |
# |          Median          |    49    |
# |           Mode           |    0     |
# |    Standard Deviation    |   5710   |
# |         Variance         | 32608380 |
# |           Min            |    0     |
# |           Max            |  56336   |
# |          Range           |  56336   |
# |     25th Percentile      |    4     |
# | 50th Percentile (Median) |    49    |
# |     75th Percentile      |   420    |
# +--------------------------+----------+
#
# Descriptive Statistics for New deaths
# +--------------------------+-------+
# |        Statistic         | Value |
# +--------------------------+-------+
# |           Mean           |  29   |
# |          Median          |   1   |
# |           Mode           |   0   |
# |    Standard Deviation    |  120  |
# |         Variance         | 14409 |
# |           Min            |   0   |
# |           Max            | 1076  |
# |          Range           | 1076  |
# |     25th Percentile      |   0   |
# | 50th Percentile (Median) |   1   |
# |     75th Percentile      |   6   |
# +--------------------------+-------+
#
# Descriptive Statistics for New recovered
# +--------------------------+----------+
# |        Statistic         |  Value   |
# +--------------------------+----------+
# |           Mean           |   934    |
# |          Median          |    22    |
# |           Mode           |    0     |
# |    Standard Deviation    |   4198   |
# |         Variance         | 17620850 |
# |           Min            |    0     |
# |           Max            |  33728   |
# |          Range           |  33728   |
# |     25th Percentile      |    0     |
# | 50th Percentile (Median) |    22    |
# |     75th Percentile      |   221    |
# +--------------------------+----------+
#
# Descriptive Statistics for Deaths / 100 Cases
# +--------------------------+-------+
# |        Statistic         | Value |
# +--------------------------+-------+
# |           Mean           |   3   |
# |          Median          |   2   |
# |           Mode           |   0   |
# |    Standard Deviation    |   3   |
# |         Variance         |  12   |
# |           Min            |   0   |
# |           Max            |  29   |
# |          Range           |  29   |
# |     25th Percentile      |   1   |
# | 50th Percentile (Median) |   2   |
# |     75th Percentile      |   4   |
# +--------------------------+-------+
#
# Descriptive Statistics for Recovered / 100 Cases
# +--------------------------+-------+
# |        Statistic         | Value |
# +--------------------------+-------+
# |           Mean           |  65   |
# |          Median          |  71   |
# |           Mode           |   0   |
# |    Standard Deviation    |  26   |
# |         Variance         |  691  |
# |           Min            |   0   |
# |           Max            |  100  |
# |          Range           |  100  |
# |     25th Percentile      |  49   |
# | 50th Percentile (Median) |  71   |
# |     75th Percentile      |  87   |
# +--------------------------+-------+
#
# Descriptive Statistics for Deaths / 100 Recovered
# +--------------------------+-------+
# |        Statistic         | Value |
# +--------------------------+-------+
# |           Mean           |  inf  |
# |          Median          |   4   |
# |           Mode           |   0   |
# |    Standard Deviation    |  nan  |
# |         Variance         |  nan  |
# |           Min            |   0   |
# |           Max            |  inf  |
# |          Range           |  inf  |
# |     25th Percentile      |   1   |
# | 50th Percentile (Median) |   4   |
# |     75th Percentile      |   6   |
# +--------------------------+-------+
#
# Descriptive Statistics for Confirmed last week
# +--------------------------+--------------+
# |        Statistic         |    Value     |
# +--------------------------+--------------+
# |           Mean           |    78682     |
# |          Median          |     5020     |
# |           Mode           |      19      |
# |    Standard Deviation    |    338274    |
# |         Variance         | 114429080258 |
# |           Min            |      10      |
# |           Max            |   3834677    |
# |          Range           |   3834667    |
# |     25th Percentile      |     1052     |
# | 50th Percentile (Median) |     5020     |
# |     75th Percentile      |    37080     |
# +--------------------------+--------------+
#
# Descriptive Statistics for 1 week change
# +--------------------------+------------+
# |        Statistic         |   Value    |
# +--------------------------+------------+
# |           Mean           |    9448    |
# |          Median          |    432     |
# |           Mode           |     0      |
# |    Standard Deviation    |   47491    |
# |         Variance         | 2255407209 |
# |           Min            |    -47     |
# |           Max            |   455582   |
# |          Range           |   455629   |
# |     25th Percentile      |     49     |
# | 50th Percentile (Median) |    432     |
# |     75th Percentile      |    3172    |
# +--------------------------+------------+
#
# Descriptive Statistics for 1 week % increase
# +--------------------------+-------+
# |        Statistic         | Value |
# +--------------------------+-------+
# |           Mean           |  14   |
# |          Median          |   7   |
# |           Mode           |   0   |
# |    Standard Deviation    |  25   |
# |         Variance         |  601  |
# |           Min            |  -4   |
# |           Max            |  226  |
# |          Range           |  230  |
# |     25th Percentile      |   3   |
# | 50th Percentile (Median) |   7   |
# |     75th Percentile      |  17   |
# +--------------------------+-------+
#
# Most Frequent WHO Region: Europe
# c:\Users\petronilo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
